# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.817303
# Nearest to called: humber, impregnated, metronome, cactus, semitones, ampex, covered, jacobites,
# Nearest to into: bopp, patience, euskara, rococo, seasoning, hiragana, televisions, foodstuffs,
# Nearest to from: portraiture, dunham, numerology, soot, subjectivism, fluctuation, dominating, reassert,
# Nearest to can: tallies, town, caverns, tamara, matrilineal, macroscopic, doublespeak, uploaded,
# Nearest to about: zander, scientifically, relying, amazonas, ftc, paigc, alamos, tipperary,
# Nearest to i: croat, font, folkestone, flamingo, parapsychology, notify, patriarchs, beelzebub,
# Nearest to many: coolant, kongo, lockout, researches, francis, mcghee, salvo, flier,
# Nearest to and: akron, lilly, delhi, gordie, stew, hksar, configurations, carcassonne,
# Nearest to first: superclass, universitaire, reputations, shelled, swimmers, byzantine, ammunition, dignitaries,
# Nearest to in: jensen, childbearing, enabled, translator, fingerspelling, malvinas, dbu, polynomial,
# Nearest to with: chanted, gesenius, launceston, srpska, assays, catenary, pluck, mouths,
# Nearest to over: nasrallah, caribs, wroc, petals, barracks, senses, deciding, delegates,
# Nearest to UNK: harpsichord, boers, nephews, ternary, consortium, overwrite, summed, kingfisher,
# Nearest to world: complements, programmed, powerfully, funerary, chants, manzarek, primetime, britanniae,
# Nearest to which: manchester, earned, biya, bonaparte, doris, injectors, galla, protestantism,
# Nearest to between: interfacing, weinstein, chorus, consecrate, aurangzeb, apollonia, kornbluth, cath,
# Average loss at step 2000: 4.376751
# Average loss at step 4000: 3.863465
# Average loss at step 6000: 3.785560
# Average loss at step 8000: 3.687386
# Average loss at step 10000: 3.614506
# Nearest to called: impregnated, humber, vegans, covered, ampex, cactus, backslash, so,
# Nearest to into: televisions, from, with, hiragana, primary, euskara, logical, stake,
# Nearest to from: at, into, in, saxo, for, with, dominating, lyrics,
# Nearest to can: may, must, cannot, would, rowena, sectarianism, caverns, uploaded,
# Nearest to about: zander, ftc, amazonas, scientifically, cotten, paigc, agnostic, relying,
# Nearest to i: they, parapsychology, he, glendale, dioceses, notebook, catalonia, masts,
# Nearest to many: some, coolant, several, kongo, all, rams, these, mika,
# Nearest to and: or, s, american, who, langue, deplete, but, on,
# Nearest to first: deut, united, byzantine, superclass, inheriting, cinematographer, bronze, telomeres,
# Nearest to in: on, at, of, from, student, after, jensen, with,
# Nearest to with: into, pluck, for, dunfermline, at, in, launceston, zaman,
# Nearest to over: wroc, sucked, ditches, interlude, car, counties, banquets, barracks,
# Nearest to UNK: flown, godf, diatomaceous, argentinean, deimos, icq, colder, rsync,
# Nearest to world: programmed, funerary, cusp, seabed, deut, periodicals, gand, manzarek,
# Nearest to which: that, this, it, also, not, honeys, decried, princely,
# Nearest to between: collaborator, phenols, donelson, in, retard, yacht, from, cali,
# Average loss at step 12000: 3.605396
# Average loss at step 14000: 3.571074
# Average loss at step 16000: 3.405255
# Average loss at step 18000: 3.458527
# Average loss at step 20000: 3.538801
# Nearest to called: impregnated, humber, ampex, analogously, dryness, covered, katsura, vegans,
# Nearest to into: with, televisions, from, logical, after, primary, euskara, hiragana,
# Nearest to from: in, at, into, saxo, between, for, tokens, around,
# Nearest to can: may, cannot, must, would, will, should, might, could,
# Nearest to about: scientifically, ftc, over, weightings, zander, cotten, amazonas, cylindrical,
# Nearest to i: ii, we, they, notebook, parapsychology, uzbekistan, pollination, kropotkin,
# Nearest to many: some, several, all, these, other, mika, various, praising,
# Nearest to and: or, in, hewson, but, towards, of, bowling, at,
# Nearest to first: united, telomeres, same, inheriting, deut, incubus, nurses, second,
# Nearest to in: at, on, from, during, and, with, by, jensen,
# Nearest to with: into, in, at, by, pluck, for, between, launceston,
# Nearest to over: wroc, ditches, about, car, posterior, gilt, banquets, counties,
# Nearest to UNK: harold, martin, prostitution, http, associates, alternating, dobbs, r,
# Nearest to world: deut, programmed, julien, funerary, gand, centuries, manzarek, zealand,
# Nearest to which: that, this, also, it, but, what, who, there,
# Nearest to between: from, phenols, collaborator, with, in, aurangzeb, grindcore, wagon,
# Average loss at step 22000: 3.500403
# Average loss at step 24000: 3.488985
# Average loss at step 26000: 3.479103
# Average loss at step 28000: 3.477072
# Average loss at step 30000: 3.501923
# Nearest to called: impregnated, named, ampex, zirconium, considered, warez, dryness, improvised,
# Nearest to into: from, televisions, primary, logical, euskara, toward, after, through,
# Nearest to from: into, through, inaccuracies, until, between, during, campania, after,
# Nearest to can: may, would, cannot, will, must, could, should, might,
# Nearest to about: over, scientifically, expatriates, confederate, zander, amazonas, ftc, billy,
# Nearest to i: ii, we, they, yeah, hoosiers, notebook, she, iii,
# Nearest to many: some, several, these, all, most, their, various, other,
# Nearest to and: or, but, in, who, of, turkic, nvidia, gila,
# Nearest to first: second, same, last, telomeres, next, deut, inheriting, nurses,
# Nearest to in: at, of, and, during, among, on, with, within,
# Nearest to with: between, for, in, pluck, against, dunfermline, doubled, into,
# Nearest to over: about, around, wroc, posterior, banquets, car, down, above,
# Nearest to UNK: argentinean, astrolabe, fronti, harold, schwenkfeld, dim, augusti, parsons,
# Nearest to world: funerary, julien, centuries, deut, programmed, seabed, lucian, tease,
# Nearest to which: this, that, what, but, it, also, these, who,
# Nearest to between: with, phenols, collaborator, from, in, lombards, cytochrome, galapagos,
# Average loss at step 32000: 3.499604
# Average loss at step 34000: 3.494724
# Average loss at step 36000: 3.457068
# Average loss at step 38000: 3.300222
# Average loss at step 40000: 3.427740
# Nearest to called: named, considered, improvised, raisin, warez, zirconium, clp, ampex,
# Nearest to into: through, from, toward, logical, euskara, hymnody, shards, televisions,
# Nearest to from: in, through, into, after, during, of, between, within,
# Nearest to can: may, will, must, would, could, cannot, should, might,
# Nearest to about: over, on, expatriates, ftc, billy, freeza, feared, cotten,
# Nearest to i: we, ii, you, they, t, she, famine, parapsychology,
# Nearest to many: some, several, these, various, those, most, each, all,
# Nearest to and: or, but, in, including, image, segmented, crossover, catan,
# Nearest to first: second, last, telomeres, next, same, fourth, nurses, bauer,
# Nearest to in: of, on, at, from, and, since, socialized, for,
# Nearest to with: between, including, by, containing, choir, dunfermline, like, pluck,
# Nearest to over: about, around, hormonal, posterior, banquets, paved, dum, headers,
# Nearest to UNK: progresses, b, controllable, smith, lamiaceae, kv, swedish, greve,
# Nearest to world: julien, funerary, centuries, deut, seabed, islets, roosevelt, lucian,
# Nearest to which: that, this, also, what, these, who, there, it,
# Nearest to between: with, phenols, from, collaborator, cytochrome, lombards, beadwork, within,
# Average loss at step 42000: 3.437850
# Average loss at step 44000: 3.453753
# Average loss at step 46000: 3.450244
# Average loss at step 48000: 3.356310
# Average loss at step 50000: 3.384706
# Nearest to called: named, improvised, considered, zirconium, used, defined, presidium, raisin,
# Nearest to into: through, from, wax, shards, toward, hymnody, with, on,
# Nearest to from: into, through, in, during, until, since, across, reuter,
# Nearest to can: may, will, could, must, would, cannot, should, might,
# Nearest to about: over, expatriates, forever, ej, bedding, ftc, scientifically, relevant,
# Nearest to i: you, we, ii, they, parapsychology, she, t, yeah,
# Nearest to many: some, several, these, those, various, most, both, all,
# Nearest to and: or, but, of, diploid, while, from, towards, hewson,
# Nearest to first: second, last, next, same, fourth, nurses, final, latter,
# Nearest to in: since, from, during, on, at, of, among, until,
# Nearest to with: between, biophysics, leftmost, samos, into, containing, motorsports, by,
# Nearest to over: around, about, hormonal, paved, nth, wroc, ditches, banquets,
# Nearest to UNK: mancha, sadler, fringed, argentinean, http, prep, brevity, von,
# Nearest to world: julien, funerary, priests, deut, islets, ramses, tease, mostar,
# Nearest to which: that, this, also, what, who, these, often, there,
# Nearest to between: with, among, within, cytochrome, in, collaborator, from, beadwork,
# Average loss at step 52000: 3.436478
# Average loss at step 54000: 3.426626
# Average loss at step 56000: 3.434774
# Average loss at step 58000: 3.399109
# Average loss at step 60000: 3.392466
# Nearest to called: named, used, considered, defined, raisin, dryness, improvised, emf,
# Nearest to into: through, from, over, toward, around, hymnody, conversely, includes,
# Nearest to from: into, through, in, across, saxo, roe, within, during,
# Nearest to can: may, would, could, will, must, cannot, should, might,
# Nearest to about: over, expatriates, forever, empirical, malfunctions, on, ej, bedding,
# Nearest to i: you, we, ii, t, they, parapsychology, dmoz, gatwick,
# Nearest to many: some, several, these, various, most, all, those, both,
# Nearest to and: or, but, including, while, prostaglandin, than, although, voter,
# Nearest to first: second, last, next, fourth, same, final, original, latter,
# Nearest to in: within, among, during, since, of, from, on, between,
# Nearest to with: between, including, in, unfalsifiable, biophysics, cretan, by, among,
# Nearest to over: around, about, paved, into, within, nth, in, hormonal,
# Nearest to UNK: adolphus, homepage, incidents, resembled, divisors, danneskj, affricate, consortium,
# Nearest to world: julien, funerary, deut, appellation, tease, ramses, universe, history,
# Nearest to which: that, what, this, however, it, these, but, also,
# Nearest to between: with, among, within, in, phenols, from, collaborator, beadwork,
# Average loss at step 62000: 3.239828
# Average loss at step 64000: 3.255827
# Average loss at step 66000: 3.402683
# Average loss at step 68000: 3.397754
# Average loss at step 70000: 3.353081
# Nearest to called: named, considered, used, raisin, emf, dryness, madox, raging,
# Nearest to into: through, from, toward, around, on, hymnody, confidential, over,
# Nearest to from: through, into, in, across, within, during, between, avestan,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to about: over, expatriates, under, on, rantissi, scientifically, confederate, empirical,
# Nearest to i: we, you, ii, g, t, yeah, notebook, jerky,
# Nearest to many: some, several, these, various, most, all, those, both,
# Nearest to and: or, but, than, which, like, while, for, of,
# Nearest to first: second, last, next, fourth, final, same, original, dominate,
# Nearest to in: within, on, for, during, from, at, since, among,
# Nearest to with: between, biophysics, including, containing, samos, among, dunfermline, daydream,
# Nearest to over: around, about, paved, hormonal, nth, into, through, within,
# Nearest to UNK: http, widen, leather, boulders, brick, zedekiah, hardwicke, h,
# Nearest to world: deut, isthmus, universe, tease, minesweeper, funerary, julien, winter,
# Nearest to which: that, this, also, what, but, however, and, these,
# Nearest to between: with, among, within, from, cytochrome, unencumbered, collaborator, lombards,
# Average loss at step 72000: 3.377200
# Average loss at step 74000: 3.347938
# Average loss at step 76000: 3.316307
# Average loss at step 78000: 3.349712
# Average loss at step 80000: 3.377183
# Nearest to called: named, used, considered, known, emf, akayev, raisin, augusta,
# Nearest to into: through, from, around, toward, over, with, confidential, across,
# Nearest to from: through, into, intentional, saxo, within, across, between, in,
# Nearest to can: may, could, will, would, must, cannot, should, might,
# Nearest to about: over, expatriates, distributes, scientifically, merchandising, forever, relevant, carolus,
# Nearest to i: we, you, ii, g, t, they, iii, evo,
# Nearest to many: several, some, these, various, most, both, all, those,
# Nearest to and: or, but, while, mozambican, including, than, langue, urbana,
# Nearest to first: second, last, next, third, fourth, final, dominate, same,
# Nearest to in: during, on, within, until, since, socialized, illustrious, at,
# Nearest to with: between, into, among, samos, during, poseidon, including, or,
# Nearest to over: around, about, into, within, paved, kwanzaa, headers, nth,
# Nearest to UNK: kara, http, chemist, harold, saxophonist, te, frantz, anconia,
# Nearest to world: julien, deut, isthmus, universe, appellation, minesweeper, funerary, priests,
# Nearest to which: that, this, also, what, but, however, honeys, conquerors,
# Nearest to between: among, within, with, in, from, establishes, cytochrome, unencumbered,
# Average loss at step 82000: 3.406838
# Average loss at step 84000: 3.411455
# Average loss at step 86000: 3.388447
# Average loss at step 88000: 3.354431
# Average loss at step 90000: 3.366947
# Nearest to called: named, used, considered, known, referred, emf, akayev, termed,
# Nearest to into: through, from, around, over, toward, on, under, turbofans,
# Nearest to from: through, into, across, within, during, between, saxo, grierson,
# Nearest to can: could, may, will, must, would, should, cannot, might,
# Nearest to about: over, expatriates, relevant, forever, rantissi, distributes, on, magnesians,
# Nearest to i: we, ii, you, g, dmoz, t, yeah, frac,
# Nearest to many: several, some, these, various, all, most, those, both,
# Nearest to and: or, but, while, including, towards, in, diploid, who,
# Nearest to first: second, last, next, final, fourth, original, same, third,
# Nearest to in: within, during, with, at, under, near, of, until,
# Nearest to with: between, in, including, by, among, perennially, chanted, coordinating,
# Nearest to over: around, about, nth, within, into, faithfulness, paved, through,
# Nearest to UNK: von, martin, alcmene, diatomaceous, lusitania, sealing, ladder, http,
# Nearest to world: isthmus, universe, deut, funerary, hebrides, appellation, minesweeper, priests,
# Nearest to which: that, also, this, but, what, these, often, honeys,
# Nearest to between: within, with, among, from, usmc, hanafi, establishes, through,
# Average loss at step 92000: 3.399503
# Average loss at step 94000: 3.251539
# Average loss at step 96000: 3.361801
# Average loss at step 98000: 3.240781
# Average loss at step 100000: 3.355930
# Nearest to called: named, akayev, used, referred, termed, considered, known, raisin,
# Nearest to into: through, from, around, over, within, onto, toward, across,
# Nearest to from: through, in, into, within, across, during, metered, gettier,
# Nearest to can: could, may, will, must, would, cannot, should, might,
# Nearest to about: over, relevant, distributes, expatriates, forever, on, rantissi, anatole,
# Nearest to i: we, you, ii, yeah, dmoz, they, treasures, quantifiers,
# Nearest to many: several, some, these, various, all, those, numerous, few,
# Nearest to and: or, but, while, although, however, including, when, who,
# Nearest to first: second, last, next, final, fourth, third, same, original,
# Nearest to in: within, during, until, from, on, near, among, throughout,
# Nearest to with: between, containing, including, into, in, using, athlon, perennially,
# Nearest to over: around, about, into, nth, posterior, within, hormonal, paved,
# Nearest to UNK: sodomy, wadsworth, ya, loew, http, muhammad, matilda, huntley,
# Nearest to world: isthmus, tezuka, hebrides, mckay, appellation, deut, universe, islets,
# Nearest to which: that, this, but, what, also, however, these, still,
# Nearest to between: with, within, among, usmc, against, through, wilmut, cytochrome,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# The model proposed is such simple in getting contexts so we can just swap labels and inputs to get CBOW analogy

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        # WOW SUCH CBOW
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From c:\users\longyuz\appdata\local\continuum\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\tf_should_use.py:175: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.967986
# Nearest to called: functionalists, marital, aac, nara, appendices, paul, contours, channel,
# Nearest to into: locating, unction, reuben, lauded, bombing, qcd, bioethics, sixties,
# Nearest to from: happily, iai, crackdown, hesitate, parrot, theodicy, fruitful, hoosiers,
# Nearest to can: yerba, hessian, catered, informa, consumerism, seaway, tendency, toro,
# Nearest to about: linz, aging, godhead, hunters, allegiance, passive, eden, planks,
# Nearest to i: finds, huck, borderline, ripped, ah, aam, announcing, dart,
# Nearest to many: teutonic, forestry, kuznetsova, nazarian, impetus, andersen, passionately, encrusted,
# Nearest to and: aquarium, badlands, totaled, corroborate, superstring, regulates, rivera, neither,
# Nearest to first: koko, perry, vorkosigan, diverted, gallardo, maryam, fermat, seder,
# Nearest to in: earthworks, keswick, slovenia, cassandra, lessened, chagrin, darrow, tac,
# Nearest to with: hardwicke, bauhaus, pittsburgh, hugely, wi, pockets, rosenbaum, differentials,
# Nearest to over: tara, insurgents, bostonians, mahdi, beats, textures, meritorious, class,
# Nearest to UNK: sundarbans, navigators, pisan, tapioca, abergavenny, entail, overload, acoustical,
# Nearest to world: exorbitant, maimonides, unborn, angelic, detergents, bernard, horticultural, autocorrelation,
# Nearest to which: july, usmc, calorimetry, ari, ferromagnetic, dodecahedron, again, koyaanisqatsi,
# Nearest to between: refutations, frustration, redaction, breakup, info, irishman, contain, quay,
# Average loss at step 2000: 4.380654
# Average loss at step 4000: 3.881806
# Average loss at step 6000: 3.802901
# Average loss at step 8000: 3.760953
# Average loss at step 10000: 3.627902
# Nearest to called: functionalists, channel, freshman, marital, lenihan, predictably, erased, elvis,
# Nearest to into: from, through, for, novelists, crustaceans, madrigal, unction, observe,
# Nearest to from: in, into, between, on, and, by, chk, anastasio,
# Nearest to can: will, may, would, must, contends, could, peloponnesian, hessian,
# Nearest to about: thabit, itv, nine, linz, insight, seven, eight, wharf,
# Nearest to i: finds, huck, he, luminous, individuals, extravagance, brisingamen, tamers,
# Nearest to many: all, some, teutonic, several, other, kuznetsova, dealing, impetus,
# Nearest to and: or, in, for, from, but, american, of, on,
# Nearest to first: sala, perry, fielded, fermat, secedes, koko, mears, mitochondrion,
# Nearest to in: on, from, and, of, at, for, with, by,
# Nearest to with: for, by, in, between, and, ess, harshly, of,
# Nearest to over: choral, eight, class, predictions, perpetrators, monatomic, loving, upcoming,
# Nearest to UNK: perceptible, earliest, veritas, categorize, rhythmically, toni, neurologist, iambic,
# Nearest to world: exorbitant, delineated, detergents, owns, categories, massacred, excess, breaking,
# Nearest to which: that, this, there, it, also, he, what, discs,
# Nearest to between: from, with, in, squeezed, like, tlatoani, by, quay,
# Average loss at step 12000: 3.584548
# Average loss at step 14000: 3.612893
# Average loss at step 16000: 3.587853
# Average loss at step 18000: 3.569158
# Average loss at step 20000: 3.544614
# Nearest to called: nitrites, functionalists, marital, lenihan, lucio, freshman, stationary, datum,
# Nearest to into: from, through, madrigal, unction, hsbc, novelists, offshore, on,
# Nearest to from: into, in, by, between, on, through, under, appendages,
# Nearest to can: will, may, would, must, could, should, might, to,
# Nearest to about: sumo, wharf, usd, thabit, camilo, veitch, fairy, itv,
# Nearest to i: huck, we, g, delta, classifying, you, tapes, oblivious,
# Nearest to many: some, several, all, these, other, encrusted, dealing, gubernatorial,
# Nearest to and: or, but, in, rhythm, elihu, of, offended, heraclea,
# Nearest to first: second, apologia, woodcock, last, koko, earliest, adverts, fielded,
# Nearest to in: at, of, from, for, and, on, under, during,
# Nearest to with: between, for, by, in, interpolating, against, through, icty,
# Nearest to over: choral, towards, under, silky, austere, deeper, predictions, evening,
# Nearest to UNK: writer, pool, dystrophy, faire, originally, questionnaire, arnaz, rijndael,
# Nearest to world: delineated, exorbitant, detergents, contiguous, loner, breaking, day, saying,
# Nearest to which: that, this, it, also, what, who, there, telomeres,
# Nearest to between: with, from, under, within, squeezed, against, satirically, by,
# Average loss at step 22000: 3.527581
# Average loss at step 24000: 3.441268
# Average loss at step 26000: 3.420004
# Average loss at step 28000: 3.470759
# Average loss at step 30000: 3.406197
# Nearest to called: nitrites, marital, lucio, stonewall, interpreted, used, functionalists, fingertips,
# Nearest to into: from, through, madrigal, unction, on, in, novelists, hsbc,
# Nearest to from: into, through, in, under, between, pamplona, neutronic, of,
# Nearest to can: may, will, would, could, must, should, might, cannot,
# Nearest to about: over, sumo, on, thabit, usd, itv, welding, aircraft,
# Nearest to i: g, we, you, t, chess, playboy, ii, huck,
# Nearest to many: some, several, these, all, most, encrusted, dealing, both,
# Nearest to and: or, but, who, while, including, although, parke, s,
# Nearest to first: second, woodcock, mistral, last, fifth, fielded, next, prokaryotes,
# Nearest to in: at, during, of, on, from, through, under, for,
# Nearest to with: between, against, by, through, icty, vaz, from, ess,
# Nearest to over: choral, towards, about, deeper, under, monatomic, oscillating, ephedrine,
# Nearest to UNK: kankan, v, viii, priory, crusading, ignaz, lehmann, normally,
# Nearest to world: exorbitant, groundbreaking, detergents, russcol, autocorrelation, poster, yalta, region,
# Nearest to which: this, that, also, often, it, there, who, what,
# Nearest to between: with, against, within, under, from, towards, squeezed, in,
# Average loss at step 32000: 3.418612
# Average loss at step 34000: 3.441184
# Average loss at step 36000: 3.366854
# Average loss at step 38000: 3.494204
# Average loss at step 40000: 3.443776
# Nearest to called: marital, nitrites, used, sakhalin, interpreted, inferential, considered, ruck,
# Nearest to into: through, from, on, unction, hsbc, madrigal, khayyam, lexicology,
# Nearest to from: into, through, during, under, in, on, chk, after,
# Nearest to can: will, may, would, could, must, should, might, cannot,
# Nearest to about: sumo, usd, itv, onscreen, thabit, vagantes, that, on,
# Nearest to i: g, we, you, t, ii, tapes, playboy, chess,
# Nearest to many: some, several, these, all, most, other, both, various,
# Nearest to and: or, but, although, resonances, thinkpad, lobbying, which, shaikh,
# Nearest to first: second, last, next, secant, landis, same, initial, raw,
# Nearest to in: during, at, from, on, under, throughout, minos, around,
# Nearest to with: between, by, through, interpolating, ess, icty, caapi, felsic,
# Nearest to over: choral, towards, deeper, ansbach, tallies, austere, under, silky,
# Nearest to UNK: vlaams, vane, thunderball, nationalized, lindsay, brim, businessmen, porphyry,
# Nearest to world: junior, groundbreaking, region, russcol, category, sleep, deadline, winter,
# Nearest to which: that, this, what, who, also, but, often, usually,
# Nearest to between: with, against, within, under, satirically, from, frustration, towards,
# Average loss at step 42000: 3.424858
# Average loss at step 44000: 3.278995
# Average loss at step 46000: 3.411466
# Average loss at step 48000: 3.430834
# Average loss at step 50000: 3.438219
# Nearest to called: nitrites, marital, used, inferential, interpreted, ruck, sakhalin, lucio,
# Nearest to into: through, from, unction, out, madrigal, on, weblog, volker,
# Nearest to from: into, through, in, chk, on, between, under, checks,
# Nearest to can: will, may, would, could, must, might, should, cannot,
# Nearest to about: sumo, on, coder, perennials, mullis, vagantes, tristar, chanted,
# Nearest to i: we, you, t, they, ii, g, she, urbanized,
# Nearest to many: some, several, these, all, both, various, most, other,
# Nearest to and: or, but, while, however, although, when, including, like,
# Nearest to first: second, last, third, next, bible, initial, fourth, bells,
# Nearest to in: at, during, under, from, on, of, between, throughout,
# Nearest to with: between, icty, against, in, by, interpolating, ess, felsic,
# Nearest to over: deeper, perpetrators, under, ansbach, maddox, choral, tallies, phosphate,
# Nearest to UNK: jesuits, morale, c, six, m, henchmen, proportionate, la,
# Nearest to world: latter, groundbreaking, sleep, exorbitant, raw, russcol, deadline, category,
# Nearest to which: this, that, what, also, who, actually, it, spence,
# Nearest to between: with, within, against, in, from, satirically, under, aves,
# Average loss at step 52000: 3.451971
# Average loss at step 54000: 3.431392
# Average loss at step 56000: 3.404207
# Average loss at step 58000: 3.279497
# Average loss at step 60000: 3.383780
# Nearest to called: nitrites, named, ruck, marital, considered, interpreted, used, referred,
# Nearest to into: through, from, unction, within, madrigal, weblog, hsbc, including,
# Nearest to from: through, into, during, including, in, between, chk, within,
# Nearest to can: could, will, may, would, must, should, might, cannot,
# Nearest to about: over, on, question, perennials, least, chanted, trash, usd,
# Nearest to i: ii, we, you, they, she, t, g, he,
# Nearest to many: some, several, these, all, both, most, various, those,
# Nearest to and: or, including, but, kamen, in, although, despite, of,
# Nearest to first: second, last, next, third, fourth, offices, bible, best,
# Nearest to in: on, during, at, within, throughout, until, under, around,
# Nearest to with: between, interpolating, against, among, ess, in, rhombicuboctahedron, during,
# Nearest to over: about, maddox, under, ansbach, phosphate, through, deeper, creation,
# Nearest to UNK: stickball, g, alimony, daniel, dr, p, outmoded, ller,
# Nearest to world: gaddis, russcol, raw, latter, detergents, poster, year, junior,
# Nearest to which: that, this, who, what, also, it, but, these,
# Nearest to between: with, against, within, satirically, from, austerlitz, under, condamine,
# Average loss at step 62000: 3.441604
# Average loss at step 64000: 3.365114
# Average loss at step 66000: 3.347258
# Average loss at step 68000: 3.386925
# Average loss at step 70000: 3.371873
# Nearest to called: named, used, referred, ruck, interpreted, known, considered, inferential,
# Nearest to into: through, from, weblog, within, on, unction, back, down,
# Nearest to from: into, through, during, in, including, chk, under, between,
# Nearest to can: will, could, may, would, must, should, might, cannot,
# Nearest to about: least, over, perennials, tristar, around, ares, suburban, usd,
# Nearest to i: ii, we, t, she, you, they, hangout, tapes,
# Nearest to many: some, several, both, all, these, various, most, their,
# Nearest to and: or, but, while, including, than, atonality, kamen, although,
# Nearest to first: second, last, next, third, earliest, earth, offices, fourth,
# Nearest to in: during, within, on, at, throughout, from, around, among,
# Nearest to with: between, against, ess, among, by, interpolating, while, icty,
# Nearest to over: under, through, ansbach, off, deeper, phosphate, maddox, about,
# Nearest to UNK: astronautics, daniel, aegis, la, memoriam, fer, writer, optimates,
# Nearest to world: russcol, raw, poster, gaddis, junior, day, shortly, latter,
# Nearest to which: that, this, also, who, what, retained, spence, these,
# Nearest to between: with, against, within, among, satirically, condamine, from, through,
# Average loss at step 72000: 3.406475
# Average loss at step 74000: 3.389556
# Average loss at step 76000: 3.347349
# Average loss at step 78000: 3.235890
# Average loss at step 80000: 3.375553
# Nearest to called: named, known, used, ruck, referred, nitrites, inferential, interpreted,
# Nearest to into: through, from, weblog, back, across, within, down, over,
# Nearest to from: through, into, under, during, using, chk, tethys, neutronic,
# Nearest to can: will, could, may, would, must, should, might, cannot,
# Nearest to about: least, over, around, question, emanated, coder, anesthetics, tristar,
# Nearest to i: g, we, ii, t, frac, you, gasolines, mail,
# Nearest to many: some, several, both, various, these, most, all, those,
# Nearest to and: or, while, but, including, of, however, although, leiserson,
# Nearest to first: second, last, next, third, articulate, initial, fourth, dislodge,
# Nearest to in: within, during, at, throughout, of, near, among, chorales,
# Nearest to with: between, interpolating, while, icty, in, preeminent, ess, by,
# Nearest to over: about, into, through, choral, ansbach, maddox, off, deeper,
# Nearest to UNK: alloying, casa, k, cnet, p, richman, proportionate, leipzig,
# Nearest to world: russcol, junior, day, exorbitant, raw, poster, gaddis, peloponnesian,
# Nearest to which: this, that, also, usually, often, what, retained, these,
# Nearest to between: with, within, against, satirically, among, austerlitz, glengarry, lifes,
# Average loss at step 82000: 3.297144
# Average loss at step 84000: 3.341345
# Average loss at step 86000: 3.343535
# Average loss at step 88000: 3.315292
# Average loss at step 90000: 3.244794
# Nearest to called: named, used, known, ruck, exporting, referred, nomen, ether,
# Nearest to into: through, within, from, across, weblog, down, unction, madrigal,
# Nearest to from: through, into, smyth, during, counterfeiting, rental, until, including,
# Nearest to can: could, will, should, may, would, must, might, cannot,
# Nearest to about: over, least, around, on, hyginus, cleanup, emanated, grinding,
# Nearest to i: you, we, ii, they, t, she, never, hangout,
# Nearest to many: some, several, various, both, all, these, most, few,
# Nearest to and: or, including, but, while, american, who, of, cx,
# Nearest to first: second, last, next, third, best, fourth, articulate, latter,
# Nearest to in: during, at, within, on, near, around, since, throughout,
# Nearest to with: between, ess, interpolating, in, against, through, bcl, marries,
# Nearest to over: maddox, about, perpetrators, ansbach, into, through, off, almost,
# Nearest to UNK: poet, politician, nikolai, le, interruption, philosopher, eric, economist,
# Nearest to world: russcol, latter, wto, groundbreaking, day, restrictive, year, mede,
# Nearest to which: that, this, also, what, who, xk, often, usually,
# Nearest to between: with, within, against, among, satirically, through, in, newest,
# Average loss at step 92000: 2.730857
# Average loss at step 94000: 3.105060
# Average loss at step 96000: 3.065331
# Average loss at step 98000: 3.222063
# Average loss at step 100000: 3.282020
# Nearest to called: named, known, used, referred, performed, nomen, prophetess, ruck,
# Nearest to into: through, down, unction, from, weblog, across, madrigal, off,
# Nearest to from: through, into, neutronic, in, chk, under, tethys, including,
# Nearest to can: could, will, must, may, would, should, might, cannot,
# Nearest to about: over, told, on, around, bonuses, poisoned, fascinating, technische,
# Nearest to i: ii, we, you, t, they, tapes, sadd, shop,
# Nearest to many: some, several, both, various, these, numerous, those, all,
# Nearest to and: or, but, however, while, including, which, nor, like,
# Nearest to first: second, last, next, third, fifth, fourth, final, current,
# Nearest to in: within, during, near, since, throughout, at, from, on,
# Nearest to with: between, by, ess, icty, interpolating, stefan, elbridge, makes,
# Nearest to over: about, off, perpetrators, maddox, through, under, into, ansbach,
# Nearest to UNK: faithfully, nikolai, guy, blackpool, graham, vlaams, oahu, achaeans,
# Nearest to world: groundbreaking, year, u, latter, dravidian, russcol, winter, vietnam,
# Nearest to which: that, this, what, often, also, who, and, but,
# Nearest to between: with, within, among, satirically, against, through, in, throughout,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
